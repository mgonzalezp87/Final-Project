# %% [markdown]
# # Data Preprocessing for Gold Price Prediction
#
# This notebook performs data cleaning, feature engineering, and scaling on the consolidated dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the consolidated dataset
df = pd.read_csv("../data/processed/consolidated.csv", parse_dates=["date"])
df.head()
# Out:
#    Unnamed: 0       date         open         high          low        close  \
# 0           0 2015-01-02  1184.000000  1194.500000  1169.500000  1186.000000
# 1           1 2015-01-05  1180.300049  1206.900024  1180.099976  1203.900024
# 2           2 2015-01-06  1203.500000  1220.000000  1203.500000  1219.300049
# 3           3 2015-01-07  1219.199951  1219.199951  1210.599976  1210.599976
# 4           4 2015-01-08  1207.000000  1215.699951  1206.300049  1208.400024
#
#    volume  dxy_close  oil_close  fedfunds  gs10  m2real  cpi  nfp  ppi
# 0     138        NaN        NaN      0.11  1.88  5015.7  NaN  NaN  NaN
# 1     470        NaN        NaN      0.11  1.88  5015.7  NaN  NaN  NaN
# 2      97        NaN        NaN      0.11  1.88  5015.7  NaN  NaN  NaN
# 3      29        NaN        NaN      0.11  1.88  5015.7  NaN  NaN  NaN
# 4      92        NaN        NaN      0.11  1.88  5015.7  NaN  NaN  NaN

# %% [markdown]
# ## Data Exploration
#
# Let's examine the dataset structure and check for missing values.

# %%
# Display basic info and summary statistics
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2552 entries, 0 to 2551
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2552 non-null   int64
#  1   date        2552 non-null   datetime64[ns]
#  2   open        2552 non-null   float64
#  3   high        2552 non-null   float64
#  4   low         2552 non-null   float64
#  5   close       2552 non-null   float64
#  6   volume      2552 non-null   int64
#  7   dxy_close   2300 non-null   float64
#  8   oil_close   2300 non-null   float64
#  9   fedfunds    2552 non-null   float64
#  10  gs10        2552 non-null   float64
#  11  m2real      2552 non-null   float64
#  12  cpi         2300 non-null   float64
#  13  nfp         2300 non-null   float64
#  14  ppi         2300 non-null   float64
# dtypes: datetime64[ns](1), float64(12), int64(2)
# memory usage: 299.2 KB
# None
#         Unnamed: 0                           date         open         high  \
# count  2552.000000                           2552  2552.000000  2552.000000
# mean   1275.500000  2020-01-30 08:23:19.373040896  1621.592163  1629.336795
# min       0.000000            2015-01-02 00:00:00  1053.699951  1062.000000
# 25%     637.750000            2017-07-18 18:00:00  1264.975006  1269.750031
# 50%    1275.500000            2020-02-01 12:00:00  1562.100037  1569.450012
# 75%    1913.250000            2022-08-12 18:00:00  1880.250031  1893.149994
# max    2551.000000            2025-02-27 00:00:00  2949.100098  2957.899902
# std     736.843267                            NaN   416.812174   419.309785
#
#                low        close         volume    dxy_close    oil_close  \
# count  2552.000000  2552.000000    2552.000000  2300.000000  2300.000000
# mean   1614.086560  1621.789733    5241.470219    98.433474    68.007961
# min    1046.199951  1050.800049       0.000000    88.589996    19.330000
# 25%    1258.325012  1265.099976      47.000000    94.389999    53.927500
# 50%    1552.250000  1564.349976     180.500000    97.430000    69.035000
# 75%    1872.950012  1883.724976     567.000000   102.589996    80.017502
# max    2933.100098  2947.899902  386334.000000   114.110001   127.980003
# std     414.563163   417.177551   28979.472150     5.205324    18.603083
#
#           fedfunds         gs10       m2real          cpi          nfp  \
# count  2552.000000  2552.000000  2552.000000  2300.000000  2300.000000
# mean      1.821669     2.512316  6284.518926   271.173434     4.612000
# min       0.050000     0.620000  5015.700000   236.916000     3.400000
# 25%       0.130000     1.760000  5573.000000   250.546000     3.700000
# 50%       1.160000     2.320000  5952.250000   259.509500     4.000000
# 75%       2.420000     3.150000  7065.600000   297.711000     4.700000
# max       5.330000     4.800000  7659.400000   319.082000    14.800000
# std       1.878346     1.072516   858.234079    26.171349     1.793372
#
#                ppi
# count  2300.000000
# mean    124.524752
# min     109.700000
# 25%     114.800000
# 50%     118.750000
# 75%     137.251000
# max     146.091000
# std      11.835098

# %%
# Drop innecessary columns

df = df.drop(columns=["Unnamed: 0"], index=1)
df.head()
# Out:
#         date         open         high          low        close  volume  \
# 0 2015-01-02  1184.000000  1194.500000  1169.500000  1186.000000     138
# 2 2015-01-06  1203.500000  1220.000000  1203.500000  1219.300049      97
# 3 2015-01-07  1219.199951  1219.199951  1210.599976  1210.599976      29
# 4 2015-01-08  1207.000000  1215.699951  1206.300049  1208.400024      92
# 5 2015-01-09  1211.099976  1220.199951  1210.300049  1216.000000      43
#
#    dxy_close  oil_close  fedfunds  gs10  m2real  cpi  nfp  ppi
# 0        NaN        NaN      0.11  1.88  5015.7  NaN  NaN  NaN
# 2        NaN        NaN      0.11  1.88  5015.7  NaN  NaN  NaN
# 3        NaN        NaN      0.11  1.88  5015.7  NaN  NaN  NaN
# 4        NaN        NaN      0.11  1.88  5015.7  NaN  NaN  NaN
# 5        NaN        NaN      0.11  1.88  5015.7  NaN  NaN  NaN

# %% [markdown]
# ## Feature Engineering
#
# ### Adding technical indicators

# %%
# Calculate 21-period EMA and 200-period EMA on the 'close' price
df["ema_21"] = df["close"].ewm(span=21, adjust=False).mean()
df["ema_200"] = df["close"].ewm(span=200, adjust=False).mean()

# Calculate 14-period RSI
delta = df["close"].diff()
gain = delta.where(delta > 0, 0)
loss = -delta.where(delta < 0, 0)
avg_gain = gain.rolling(window=14, min_periods=14).mean()
avg_loss = loss.rolling(window=14, min_periods=14).mean()
rs = avg_gain / avg_loss
df["rsi_14"] = 100 - (100 / (1 + rs))

# Display the new columns
df[["close", "ema_21", "ema_200", "rsi_14"]].tail()
# Out:
#             close       ema_21      ema_200     rsi_14
# 2547  2937.600098  2862.293305  2573.843503  72.283579
# 2548  2947.899902  2870.075723  2577.565458  71.142426
# 2549  2904.500000  2873.205203  2580.818538  58.719342
# 2550  2916.800049  2877.168371  2584.161637  57.858132
# 2551  2883.199951  2877.716696  2587.137143  54.450256

# %%
# Quickly drop null values
df = df.dropna()

# %% [markdown]
# ## We'll create a target variable representing the difference between the open price and the high or low price whichever is greater

# %%
# Define a function to compute the target for each row
def compute_target(row):
    diff_high = row["high"] - row["open"]
    diff_low = row["low"] - row["open"]
    return diff_high if abs(diff_high) >= abs(diff_low) else diff_low

# Apply the function to create the target column
# (Assumes your consolidated data includes columns "Open", "High", "Low")
df["target"] = df.apply(compute_target, axis=1)

df.head()
# Out:
#           date         open         high          low        close  volume  \
# 252 2016-01-04  1063.400024  1082.500000  1063.199951  1075.099976     143
# 253 2016-01-05  1075.599976  1081.500000  1075.300049  1078.400024      82
# 254 2016-01-06  1081.599976  1093.699951  1081.599976  1091.900024      52
# 255 2016-01-07  1091.599976  1109.400024  1091.599976  1107.699951     122
# 256 2016-01-08  1111.099976  1111.099976  1093.000000  1097.800049      98
#
#      dxy_close  oil_close  fedfunds  gs10  m2real      cpi  nfp    ppi  \
# 252  98.870003  37.220001      0.34  2.09  5255.9  236.916  4.8  109.7
# 253  99.400002  36.419998      0.34  2.09  5255.9  236.916  4.8  109.7
# 254  99.180000  34.230000      0.34  2.09  5255.9  236.916  4.8  109.7
# 255  98.220001  33.750000      0.34  2.09  5255.9  236.916  4.8  109.7
# 256  98.540001  33.549999      0.34  2.09  5255.9  236.916  4.8  109.7
#
#           ema_21      ema_200     rsi_14     target
# 252  1072.147921  1131.009838  49.414808  19.099976
# 253  1072.716294  1130.486357  54.727431   5.900024
# 254  1074.460269  1130.102414  59.259268  12.099976
# 255  1077.482059  1129.879504  59.440556  17.800049
# 256  1079.329149  1129.560305  66.785744 -18.099976

# %% [markdown]
# ## Scaling Features
#
# We will scale the numerical features (excluding the date and target) using StandardScaler.

# %%
from sklearn.preprocessing import StandardScaler

# Identify feature columns (excluding 'date' and 'target')
features = df.columns.difference(["date", "target"])

scaler = StandardScaler()
df_scaled = df.copy()
df_scaled[features] = scaler.fit_transform(df[features])

df_scaled.head()
# Out:
#           date      open      high       low     close    volume  dxy_close  \
# 252 2016-01-04 -1.492593 -1.455997 -1.483192 -1.463562 -0.175159   0.083880
# 253 2016-01-05 -1.462683 -1.458433 -1.453351 -1.455477 -0.177236   0.185721
# 254 2016-01-06 -1.447974 -1.428712 -1.437814 -1.422404 -0.178257   0.143447
# 255 2016-01-07 -1.423458 -1.390464 -1.413153 -1.383697 -0.175874  -0.041019
# 256 2016-01-08 -1.375652 -1.386323 -1.409700 -1.407950 -0.176691   0.020469
#
#      oil_close  fedfunds      gs10    m2real       cpi       nfp       ppi  \
# 252  -1.655352 -0.882534 -0.413267 -1.447047 -1.309252  0.104853 -1.252882
# 253  -1.698365 -0.882534 -0.413267 -1.447047 -1.309252  0.104853 -1.252882
# 254  -1.816113 -0.882534 -0.413267 -1.447047 -1.309252  0.104853 -1.252882
# 255  -1.841921 -0.882534 -0.413267 -1.447047 -1.309252  0.104853 -1.252882
# 256  -1.852674 -0.882534 -0.413267 -1.447047 -1.309252  0.104853 -1.252882
#
#        ema_21   ema_200    rsi_14     target
# 252 -1.478729 -1.352997 -0.220203  19.099976
# 253 -1.477311 -1.354477  0.087538   5.900024
# 254 -1.472958 -1.355563  0.350051  12.099976
# 255 -1.465417 -1.356193  0.360552  17.800049
# 256 -1.460807 -1.357096  0.786032 -18.099976

# %% [markdown]
# ## Save Cleaned Data
#
# Save the cleaned and scaled data to a new CSV file for future modeling.

# %%
# Save the cleaned and scaled data to a CSV file
df_scaled.to_csv("../data/processed/clean_dataset.csv", index=False)
print("Cleaned data saved to data/processed/clean_dataset.csv")
# Out:
# Cleaned data saved to data/processed/clean_dataset.csv
